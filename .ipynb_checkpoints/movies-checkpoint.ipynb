# %%
from importlib import reload  # Python 3.4+
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker
from ndbc_api import NdbcApi
import concurrent.futures
from tqdm.contrib.concurrent import process_map, thread_map
from tqdm.autonotebook import tqdm
from xmovie import Movie

# %%
extrema = lambda x: (np.min(x), np.max(x))

# %%
# %matplotlib notebook
ds = xr.open_dataset("/Users/anthonymeza/Downloads/bsose_i105_2008to2012_monthly_SSH.nc")
ETAN = ds.ETAN
vmin, vmax = extrema(ETAN)
ETAN = ETAN.where(ETAN != 0)
fig, ax = plt.subplots()
ETAN.isel(time = 0).plot(ax = ax)

fig
# Out:
# <div id='ca071ccc-3608-4e74-81e2-92f632f50707'></div>

# %%
fig, ax = plt.subplots()

ETAN.isel(time = -1).plot(ax = ax)
fig
# Out:
# <div id='98607b55-a925-4d47-8b4a-e3c61c232716'></div>

# %%
mov = Movie(ETAN, vmin = -2, vmax = 2)
mov.save('movie.mp4', overwrite_existing = True)
# Out:
# <div id='b7e65722-9a36-4bfa-93ee-5a2d7de8db66'></div>
# <div id='cf93b0ab-fe25-4915-90eb-e3dc4ff231b5'></div>
# <div id='e7816db0-c8c3-46f1-83d3-4cfd55905daf'></div>
# <div id='2d8c4753-9891-4726-8129-168b3eb6b064'></div>
# <div id='693f22e8-2afd-4031-8317-097f6e8913f6'></div>
# <div id='8500338f-d4ac-444b-8c64-df66c9561999'></div>
# <div id='2bbac22c-e0e0-40cc-aee5-a927dd57547a'></div>
# <div id='cf31f70d-4161-4159-8f47-393fb32c8c7b'></div>
